# %% [markdown]
# # Sección nueva

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# ======================================================================
# 1. Configuración
# ======================================================================
COLUMNAS_OBJETIVO = [
    'hdl_cholesterol_human',
    'hemoglobin(hgb)_human'
]

ARCHIVOS = {
    'train': 'Train.csv',
    'test': 'Test.csv'
}

# ======================================================================
# 2. Funciones de Limpieza de Datos Mejoradas
# ======================================================================
def extraer_numeros(valor):
    """Extrae valores numéricos de cadenas complejas"""
    try:
        coincidencias = re.findall(r'-?\d+\.?\d*', str(valor))
        return float(coincidencias[0]) if coincidencias else np.nan
    except:
        return np.nan

def limpiar_columna(df, col):
    """Limpieza avanzada para columnas objetivo"""
    print(f"Valores originales en {col}: {df[col].unique()[:10]}")
    df[col] = pd.to_numeric(df[col], errors='coerce')
    print(f"Valores después de conversión a numérico en {col}: {df[col].unique()[:10]}")
    df[col] = df[col].fillna(df[col].median())
    return df

def procesar_numericos(df):
    """Procesamiento completo de columnas numéricas"""
    print("\n=== LIMPIEZA DE DATOS ===")

    # Procesar columnas objetivo
    for col in COLUMNAS_OBJETIVO:
        if col in df.columns:
            print(f"\nProcesando {col}:")
            df[col] = df[col].astype(str)  # Asegurarse de que sea una cadena
            df[col] = df[col].replace({'ok': 1, 'low': 0, 'high': 2})  # Codificación manual
            df[col] = pd.to_numeric(df[col], errors='coerce')  # Convertir a numérico
            df[col] = df[col].fillna(df[col].median())  # Imputar NaNs
            print(f"NaNs: {df[col].isna().sum()}")

    # Procesar absorbancias y sensores
    columnas_numericas = [f'absorbance{i}' for i in range(170)] + ['temperature', 'humidity']
    for col in columnas_numericas:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')
            print(f"NaNs en {col} antes de imputación: {df[col].isna().sum()}")
            df[col] = df[col].fillna(df[col].median())
            print(f"NaNs en {col} después de imputación: {df[col].isna().sum()}")

    return df

# ======================================================================
# 3. Pipeline de Procesamiento
# ======================================================================
def cargar_y_procesar(ruta, pca=None, scaler=None, es_entrenamiento=False):
    try:
        df = pd.read_csv(ruta)
        print(f"\n=== PROCESANDO {ruta} ===")
        print(f"Registros : {len(df):,}")

        # Limpieza avanzada
        df = procesar_numericos(df)

        # Reducción dimensional
        absorb_cols = [f'absorbance{i}' for i in range(170)]
        if es_entrenamiento or pca is None:
            pca = PCA(n_components=0.95)
            componentes = pca.fit_transform(df[absorb_cols])
        else:
            componentes = pca.transform(df[absorb_cols])

        df = pd.concat([df.drop(columns=absorb_cols),
                       pd.DataFrame(componentes, columns=[f'pca_{i}' for i in range(componentes.shape[1])])],
                      axis=1)

        # Escalado
        features = [col for col in df.columns if col.startswith('pca_')] + ['temperature', 'humidity']
        if scaler:
            X = scaler.transform(df[features]) if not es_entrenamiento else scaler.fit_transform(df[features])
        else:
            scaler = RobustScaler()
            X = scaler.fit_transform(df[features])

        # Extraer objetivos
        y = df[COLUMNAS_OBJETIVO] if es_entrenamiento else None

        return X, y, pca, scaler, df['Reading_ID']

    except Exception as e:
        print(f"Error procesando {ruta}: {str(e)}")
        raise

# ======================================================================
# 4. Modelo de Deep Learning Optimizado
# ======================================================================
def construir_modelo(input_dim):
    inputs = Input(shape=(input_dim,))

    # Capas ocultas
    x = Dense(128, activation='relu', kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    x = Dense(64, activation='relu', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # Salidas
    salida_0 = Dense(1, name='salida_0')(x)
    salida_1 = Dense(1, name='salida_1')(x)

    model = Model(inputs=inputs, outputs=[salida_0, salida_1])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='mean_squared_error',
                  metrics=['mae', 'mae'])  # Especificar métricas para ambas salidas
    return model

# ======================================================================
# 5. Entrenamiento del Modelo
# ======================================================================
def entrenar_modelo(X_train, y_train):
    model = construir_modelo(X_train.shape[1])
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    history = model.fit(X_train,
                        [y_train[col] for col in COLUMNAS_OBJETIVO],
                        validation_split=0.2,
                        epochs=100,
                        batch_size=32,
                        callbacks=[early_stopping],
                        verbose=1)
    return model, history

# ======================================================================
# 6. Predicción y Guardado de Resultados
# ======================================================================
def predecir_y_guardar(model, X_test, ids):
    predicciones = model.predict(X_test)

    # Convertir las predicciones a un DataFrame
    resultados = pd.DataFrame({
        COLUMNAS_OBJETIVO[0]: predicciones[0].flatten(),  # Salida 1
        COLUMNAS_OBJETIVO[1]: predicciones[1].flatten()   # Salida 2
    })

    resultados['Reading_ID'] = ids
    resultados.to_csv('predicciones.csv', index=False)
    print("Predicciones guardadas en 'predicciones.csv'.")

# ======================================================================
# 7. Ejecución del Pipeline Completo
# ======================================================================
if __name__ == "__main__":
    # Cargar y procesar datos
    X_train, y_train, pca, scaler, _ = cargar_y_procesar(ARCHIVOS['train'], es_entrenamiento=True)
    X_test, _, _, _, ids_test = cargar_y_procesar(ARCHIVOS['test'], pca=pca, scaler=scaler)

    # Entrenar modelo
    model, history = entrenar_modelo(X_train, y_train)

    # Predecir y guardar resultados
    predecir_y_guardar(model, X_test, ids_test)
# Out:
# === PROCESANDO Train.csv ===
# Registros : 13,140
#
# === LIMPIEZA DE DATOS ===
#
# Procesando hdl_cholesterol_human:
# NaNs: 0
#
# Procesando hemoglobin(hgb)_human:
# NaNs: 0
# NaNs en absorbance0 antes de imputación: 0
# NaNs en absorbance0 después de imputación: 0
# NaNs en absorbance1 antes de imputación: 0
# NaNs en absorbance1 después de imputación: 0
# NaNs en absorbance2 antes de imputación: 0
# NaNs en absorbance2 después de imputación: 0
# NaNs en absorbance3 antes de imputación: 0
# NaNs en absorbance3 después de imputación: 0
# NaNs en absorbance4 antes de imputación: 0
# NaNs en absorbance4 después de imputación: 0
# NaNs en absorbance5 antes de imputación: 0
# NaNs en absorbance5 después de imputación: 0
# NaNs en absorbance6 antes de imputación: 0
# NaNs en absorbance6 después de imputación: 0
# NaNs en absorbance7 antes de imputación: 0
# NaNs en absorbance7 después de imputación: 0
# NaNs en absorbance8 antes de imputación: 0
# NaNs en absorbance8 después de imputación: 0
# NaNs en absorbance9 antes de imputación: 0
# NaNs en absorbance9 después de imputación: 0
# NaNs en absorbance10 antes de imputación: 0
# NaNs en absorbance10 después de imputación: 0
# NaNs en absorbance11 antes de imputación: 0
# NaNs en absorbance11 después de imputación: 0
# NaNs en absorbance12 antes de imputación: 0
# NaNs en absorbance12 después de imputación: 0
# NaNs en absorbance13 antes de imputación: 0
# NaNs en absorbance13 después de imputación: 0
# NaNs en absorbance14 antes de imputación: 0
# NaNs en absorbance14 después de imputación: 0
# NaNs en absorbance15 antes de imputación: 0
# NaNs en absorbance15 después de imputación: 0
# NaNs en absorbance16 antes de imputación: 0
# NaNs en absorbance16 después de imputación: 0
# NaNs en absorbance17 antes de imputación: 0
# NaNs en absorbance17 después de imputación: 0
# NaNs en absorbance18 antes de imputación: 0
# NaNs en absorbance18 después de imputación: 0
# NaNs en absorbance19 antes de imputación: 0
# NaNs en absorbance19 después de imputación: 0
# NaNs en absorbance20 antes de imputación: 0
# NaNs en absorbance20 después de imputación: 0
# NaNs en absorbance21 antes de imputación: 0
# NaNs en absorbance21 después de imputación: 0
# NaNs en absorbance22 antes de imputación: 0
# NaNs en absorbance22 después de imputación: 0
# NaNs en absorbance23 antes de imputación: 0
# NaNs en absorbance23 después de imputación: 0
# NaNs en absorbance24 antes de imputación: 0
# NaNs en absorbance24 después de imputación: 0
# NaNs en absorbance25 antes de imputación: 0
# NaNs en absorbance25 después de imputación: 0
# NaNs en absorbance26 antes de imputación: 0
# NaNs en absorbance26 después de imputación: 0
# NaNs en absorbance27 antes de imputación: 0
# NaNs en absorbance27 después de imputación: 0
# NaNs en absorbance28 antes de imputación: 0
# NaNs en absorbance28 después de imputación: 0
# NaNs en absorbance29 antes de imputación: 0
# NaNs en absorbance29 después de imputación: 0
# NaNs en absorbance30 antes de imputación: 0
# NaNs en absorbance30 después de imputación: 0
# NaNs en absorbance31 antes de imputación: 0
# NaNs en absorbance31 después de imputación: 0
# NaNs en absorbance32 antes de imputación: 0
# NaNs en absorbance32 después de imputación: 0
# NaNs en absorbance33 antes de imputación: 0
# NaNs en absorbance33 después de imputación: 0
# NaNs en absorbance34 antes de imputación: 0
# NaNs en absorbance34 después de imputación: 0
# NaNs en absorbance35 antes de imputación: 0
# NaNs en absorbance35 después de imputación: 0
# NaNs en absorbance36 antes de imputación: 0
# NaNs en absorbance36 después de imputación: 0
# NaNs en absorbance37 antes de imputación: 0
# NaNs en absorbance37 después de imputación: 0
# NaNs en absorbance38 antes de imputación: 0
# NaNs en absorbance38 después de imputación: 0
# NaNs en absorbance39 antes de imputación: 0
# NaNs en absorbance39 después de imputación: 0
# NaNs en absorbance40 antes de imputación: 0
# NaNs en absorbance40 después de imputación: 0
# NaNs en absorbance41 antes de imputación: 0
# NaNs en absorbance41 después de imputación: 0
# NaNs en absorbance42 antes de imputación: 0
# NaNs en absorbance42 después de imputación: 0
# NaNs en absorbance43 antes de imputación: 0
# NaNs en absorbance43 después de imputación: 0
# NaNs en absorbance44 antes de imputación: 0
# NaNs en absorbance44 después de imputación: 0
# NaNs en absorbance45 antes de imputación: 0
# NaNs en absorbance45 después de imputación: 0
# NaNs en absorbance46 antes de imputación: 0
# NaNs en absorbance46 después de imputación: 0
# NaNs en absorbance47 antes de imputación: 0
# <ipython-input-9-85c93566b03f>:53: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace({'ok': 1, 'low': 0, 'high': 2})  # Codificación manual
# <ipython-input-9-85c93566b03f>:53: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace({'ok': 1, 'low': 0, 'high': 2})  # Codificación manual
# NaNs en absorbance47 después de imputación: 0
# NaNs en absorbance48 antes de imputación: 0
# NaNs en absorbance48 después de imputación: 0
# NaNs en absorbance49 antes de imputación: 0
# NaNs en absorbance49 después de imputación: 0
# NaNs en absorbance50 antes de imputación: 0
# NaNs en absorbance50 después de imputación: 0
# NaNs en absorbance51 antes de imputación: 0
# NaNs en absorbance51 después de imputación: 0
# NaNs en absorbance52 antes de imputación: 0
# NaNs en absorbance52 después de imputación: 0
# NaNs en absorbance53 antes de imputación: 0
# NaNs en absorbance53 después de imputación: 0
# NaNs en absorbance54 antes de imputación: 0
# NaNs en absorbance54 después de imputación: 0
# NaNs en absorbance55 antes de imputación: 0
# NaNs en absorbance55 después de imputación: 0
# NaNs en absorbance56 antes de imputación: 0
# NaNs en absorbance56 después de imputación: 0
# NaNs en absorbance57 antes de imputación: 0
# NaNs en absorbance57 después de imputación: 0
# NaNs en absorbance58 antes de imputación: 0
# NaNs en absorbance58 después de imputación: 0
# NaNs en absorbance59 antes de imputación: 0
# NaNs en absorbance59 después de imputación: 0
# NaNs en absorbance60 antes de imputación: 0
# NaNs en absorbance60 después de imputación: 0
# NaNs en absorbance61 antes de imputación: 0
# NaNs en absorbance61 después de imputación: 0
# NaNs en absorbance62 antes de imputación: 0
# NaNs en absorbance62 después de imputación: 0
# NaNs en absorbance63 antes de imputación: 0
# NaNs en absorbance63 después de imputación: 0
# NaNs en absorbance64 antes de imputación: 0
# NaNs en absorbance64 después de imputación: 0
# NaNs en absorbance65 antes de imputación: 0
# NaNs en absorbance65 después de imputación: 0
# NaNs en absorbance66 antes de imputación: 0
# NaNs en absorbance66 después de imputación: 0
# NaNs en absorbance67 antes de imputación: 0
# NaNs en absorbance67 después de imputación: 0
# NaNs en absorbance68 antes de imputación: 0
# NaNs en absorbance68 después de imputación: 0
# NaNs en absorbance69 antes de imputación: 0
# NaNs en absorbance69 después de imputación: 0
# NaNs en absorbance70 antes de imputación: 0
# NaNs en absorbance70 después de imputación: 0
# NaNs en absorbance71 antes de imputación: 0
# NaNs en absorbance71 después de imputación: 0
# NaNs en absorbance72 antes de imputación: 0
# NaNs en absorbance72 después de imputación: 0
# NaNs en absorbance73 antes de imputación: 0
# NaNs en absorbance73 después de imputación: 0
# NaNs en absorbance74 antes de imputación: 0
# NaNs en absorbance74 después de imputación: 0
# NaNs en absorbance75 antes de imputación: 0
# NaNs en absorbance75 después de imputación: 0
# NaNs en absorbance76 antes de imputación: 0
# NaNs en absorbance76 después de imputación: 0
# NaNs en absorbance77 antes de imputación: 0
# NaNs en absorbance77 después de imputación: 0
# NaNs en absorbance78 antes de imputación: 0
# NaNs en absorbance78 después de imputación: 0
# NaNs en absorbance79 antes de imputación: 0
# NaNs en absorbance79 después de imputación: 0
# NaNs en absorbance80 antes de imputación: 0
# NaNs en absorbance80 después de imputación: 0
# NaNs en absorbance81 antes de imputación: 0
# NaNs en absorbance81 después de imputación: 0
# NaNs en absorbance82 antes de imputación: 0
# NaNs en absorbance82 después de imputación: 0
# NaNs en absorbance83 antes de imputación: 0
# NaNs en absorbance83 después de imputación: 0
# NaNs en absorbance84 antes de imputación: 0
# NaNs en absorbance84 después de imputación: 0
# NaNs en absorbance85 antes de imputación: 0
# NaNs en absorbance85 después de imputación: 0
# NaNs en absorbance86 antes de imputación: 0
# NaNs en absorbance86 después de imputación: 0
# NaNs en absorbance87 antes de imputación: 0
# NaNs en absorbance87 después de imputación: 0
# NaNs en absorbance88 antes de imputación: 0
# NaNs en absorbance88 después de imputación: 0
# NaNs en absorbance89 antes de imputación: 0
# NaNs en absorbance89 después de imputación: 0
# NaNs en absorbance90 antes de imputación: 0
# NaNs en absorbance90 después de imputación: 0
# NaNs en absorbance91 antes de imputación: 0
# NaNs en absorbance91 después de imputación: 0
# NaNs en absorbance92 antes de imputación: 0
# NaNs en absorbance92 después de imputación: 0
# NaNs en absorbance93 antes de imputación: 0
# NaNs en absorbance93 después de imputación: 0
# NaNs en absorbance94 antes de imputación: 0
# NaNs en absorbance94 después de imputación: 0
# NaNs en absorbance95 antes de imputación: 0
# NaNs en absorbance95 después de imputación: 0
# NaNs en absorbance96 antes de imputación: 0
# NaNs en absorbance96 después de imputación: 0
# NaNs en absorbance97 antes de imputación: 0
# NaNs en absorbance97 después de imputación: 0
# NaNs en absorbance98 antes de imputación: 0
# NaNs en absorbance98 después de imputación: 0
# NaNs en absorbance99 antes de imputación: 0
# NaNs en absorbance99 después de imputación: 0
# NaNs en absorbance100 antes de imputación: 0
# NaNs en absorbance100 después de imputación: 0
# NaNs en absorbance101 antes de imputación: 0
# NaNs en absorbance101 después de imputación: 0
# NaNs en absorbance102 antes de imputación: 0
# NaNs en absorbance102 después de imputación: 0
# NaNs en absorbance103 antes de imputación: 0
# NaNs en absorbance103 después de imputación: 0
# NaNs en absorbance104 antes de imputación: 0
# NaNs en absorbance104 después de imputación: 0
# NaNs en absorbance105 antes de imputación: 0
# NaNs en absorbance105 después de imputación: 0
# NaNs en absorbance106 antes de imputación: 0
# NaNs en absorbance106 después de imputación: 0
# NaNs en absorbance107 antes de imputación: 0
# NaNs en absorbance107 después de imputación: 0
# NaNs en absorbance108 antes de imputación: 0
# NaNs en absorbance108 después de imputación: 0
# NaNs en absorbance109 antes de imputación: 0
# NaNs en absorbance109 después de imputación: 0
# NaNs en absorbance110 antes de imputación: 0
# NaNs en absorbance110 después de imputación: 0
# NaNs en absorbance111 antes de imputación: 0
# NaNs en absorbance111 después de imputación: 0
# NaNs en absorbance112 antes de imputación: 0
# NaNs en absorbance112 después de imputación: 0
# NaNs en absorbance113 antes de imputación: 0
# NaNs en absorbance113 después de imputación: 0
# NaNs en absorbance114 antes de imputación: 0
# NaNs en absorbance114 después de imputación: 0
# NaNs en absorbance115 antes de imputación: 0
# NaNs en absorbance115 después de imputación: 0
# NaNs en absorbance116 antes de imputación: 0
# NaNs en absorbance116 después de imputación: 0
# NaNs en absorbance117 antes de imputación: 0
# NaNs en absorbance117 después de imputación: 0
# NaNs en absorbance118 antes de imputación: 0
# NaNs en absorbance118 después de imputación: 0
# NaNs en absorbance119 antes de imputación: 0
# NaNs en absorbance119 después de imputación: 0
# NaNs en absorbance120 antes de imputación: 0
# NaNs en absorbance120 después de imputación: 0
# NaNs en absorbance121 antes de imputación: 0
# NaNs en absorbance121 después de imputación: 0
# NaNs en absorbance122 antes de imputación: 0
# NaNs en absorbance122 después de imputación: 0
# NaNs en absorbance123 antes de imputación: 0
# NaNs en absorbance123 después de imputación: 0
# NaNs en absorbance124 antes de imputación: 0
# NaNs en absorbance124 después de imputación: 0
# NaNs en absorbance125 antes de imputación: 0
# NaNs en absorbance125 después de imputación: 0
# NaNs en absorbance126 antes de imputación: 0
# NaNs en absorbance126 después de imputación: 0
# NaNs en absorbance127 antes de imputación: 0
# NaNs en absorbance127 después de imputación: 0
# NaNs en absorbance128 antes de imputación: 0
# NaNs en absorbance128 después de imputación: 0
# NaNs en absorbance129 antes de imputación: 0
# NaNs en absorbance129 después de imputación: 0
# NaNs en absorbance130 antes de imputación: 0
# NaNs en absorbance130 después de imputación: 0
# NaNs en absorbance131 antes de imputación: 0
# NaNs en absorbance131 después de imputación: 0
# NaNs en absorbance132 antes de imputación: 0
# NaNs en absorbance132 después de imputación: 0
# NaNs en absorbance133 antes de imputación: 0
# NaNs en absorbance133 después de imputación: 0
# NaNs en absorbance134 antes de imputación: 0
# NaNs en absorbance134 después de imputación: 0
# NaNs en absorbance135 antes de imputación: 0
# NaNs en absorbance135 después de imputación: 0
# NaNs en absorbance136 antes de imputación: 0
# NaNs en absorbance136 después de imputación: 0
# NaNs en absorbance137 antes de imputación: 0
# NaNs en absorbance137 después de imputación: 0
# NaNs en absorbance138 antes de imputación: 0
# NaNs en absorbance138 después de imputación: 0
# NaNs en absorbance139 antes de imputación: 0
# NaNs en absorbance139 después de imputación: 0
# NaNs en absorbance140 antes de imputación: 0
# NaNs en absorbance140 después de imputación: 0
# NaNs en absorbance141 antes de imputación: 0
# NaNs en absorbance141 después de imputación: 0
# NaNs en absorbance142 antes de imputación: 0
# NaNs en absorbance142 después de imputación: 0
# NaNs en absorbance143 antes de imputación: 0
# NaNs en absorbance143 después de imputación: 0
# NaNs en absorbance144 antes de imputación: 0
# NaNs en absorbance144 después de imputación: 0
# NaNs en absorbance145 antes de imputación: 0
# NaNs en absorbance145 después de imputación: 0
# NaNs en absorbance146 antes de imputación: 0
# NaNs en absorbance146 después de imputación: 0
# NaNs en absorbance147 antes de imputación: 0
# NaNs en absorbance147 después de imputación: 0
# NaNs en absorbance148 antes de imputación: 0
# NaNs en absorbance148 después de imputación: 0
# NaNs en absorbance149 antes de imputación: 0
# NaNs en absorbance149 después de imputación: 0
# NaNs en absorbance150 antes de imputación: 0
# NaNs en absorbance150 después de imputación: 0
# NaNs en absorbance151 antes de imputación: 0
# NaNs en absorbance151 después de imputación: 0
# NaNs en absorbance152 antes de imputación: 0
# NaNs en absorbance152 después de imputación: 0
# NaNs en absorbance153 antes de imputación: 0
# NaNs en absorbance153 después de imputación: 0
# NaNs en absorbance154 antes de imputación: 0
# NaNs en absorbance154 después de imputación: 0
# NaNs en absorbance155 antes de imputación: 0
# NaNs en absorbance155 después de imputación: 0
# NaNs en absorbance156 antes de imputación: 0
# NaNs en absorbance156 después de imputación: 0
# NaNs en absorbance157 antes de imputación: 0
# NaNs en absorbance157 después de imputación: 0
# NaNs en absorbance158 antes de imputación: 0
# NaNs en absorbance158 después de imputación: 0
# NaNs en absorbance159 antes de imputación: 0
# NaNs en absorbance159 después de imputación: 0
# NaNs en absorbance160 antes de imputación: 0
# NaNs en absorbance160 después de imputación: 0
# NaNs en absorbance161 antes de imputación: 0
# NaNs en absorbance161 después de imputación: 0
# NaNs en absorbance162 antes de imputación: 0
# NaNs en absorbance162 después de imputación: 0
# NaNs en absorbance163 antes de imputación: 0
# NaNs en absorbance163 después de imputación: 0
# NaNs en absorbance164 antes de imputación: 0
# NaNs en absorbance164 después de imputación: 0
# NaNs en absorbance165 antes de imputación: 0
# NaNs en absorbance165 después de imputación: 0
# NaNs en absorbance166 antes de imputación: 0
# NaNs en absorbance166 después de imputación: 0
# NaNs en absorbance167 antes de imputación: 0
# NaNs en absorbance167 después de imputación: 0
# NaNs en absorbance168 antes de imputación: 0
# NaNs en absorbance168 después de imputación: 0
# NaNs en absorbance169 antes de imputación: 0
# NaNs en absorbance169 después de imputación: 0
# NaNs en temperature antes de imputación: 0
# NaNs en temperature después de imputación: 0
# NaNs en humidity antes de imputación: 0
# NaNs en humidity después de imputación: 0
#
# === PROCESANDO Test.csv ===
# Registros : 3,660
#
# === LIMPIEZA DE DATOS ===
# NaNs en absorbance0 antes de imputación: 0
# NaNs en absorbance0 después de imputación: 0
# NaNs en absorbance1 antes de imputación: 0
# NaNs en absorbance1 después de imputación: 0
# NaNs en absorbance2 antes de imputación: 0
# NaNs en absorbance2 después de imputación: 0
# NaNs en absorbance3 antes de imputación: 0
# NaNs en absorbance3 después de imputación: 0
# NaNs en absorbance4 antes de imputación: 0
# NaNs en absorbance4 después de imputación: 0
# NaNs en absorbance5 antes de imputación: 0
# NaNs en absorbance5 después de imputación: 0
# NaNs en absorbance6 antes de imputación: 0
# NaNs en absorbance6 después de imputación: 0
# NaNs en absorbance7 antes de imputación: 0
# NaNs en absorbance7 después de imputación: 0
# NaNs en absorbance8 antes de imputación: 0
# NaNs en absorbance8 después de imputación: 0
# NaNs en absorbance9 antes de imputación: 0
# NaNs en absorbance9 después de imputación: 0
# NaNs en absorbance10 antes de imputación: 0
# NaNs en absorbance10 después de imputación: 0
# NaNs en absorbance11 antes de imputación: 0
# NaNs en absorbance11 después de imputación: 0
# NaNs en absorbance12 antes de imputación: 0
# NaNs en absorbance12 después de imputación: 0
# NaNs en absorbance13 antes de imputación: 0
# NaNs en absorbance13 después de imputación: 0
# NaNs en absorbance14 antes de imputación: 0
# NaNs en absorbance14 después de imputación: 0
# NaNs en absorbance15 antes de imputación: 0
# NaNs en absorbance15 después de imputación: 0
# NaNs en absorbance16 antes de imputación: 0
# NaNs en absorbance16 después de imputación: 0
# NaNs en absorbance17 antes de imputación: 0
# NaNs en absorbance17 después de imputación: 0
# NaNs en absorbance18 antes de imputación: 0
# NaNs en absorbance18 después de imputación: 0
# NaNs en absorbance19 antes de imputación: 0
# NaNs en absorbance19 después de imputación: 0
# NaNs en absorbance20 antes de imputación: 0
# NaNs en absorbance20 después de imputación: 0
# NaNs en absorbance21 antes de imputación: 0
# NaNs en absorbance21 después de imputación: 0
# NaNs en absorbance22 antes de imputación: 0
# NaNs en absorbance22 después de imputación: 0
# NaNs en absorbance23 antes de imputación: 0
# NaNs en absorbance23 después de imputación: 0
# NaNs en absorbance24 antes de imputación: 0
# NaNs en absorbance24 después de imputación: 0
# NaNs en absorbance25 antes de imputación: 0
# NaNs en absorbance25 después de imputación: 0
# NaNs en absorbance26 antes de imputación: 0
# NaNs en absorbance26 después de imputación: 0
# NaNs en absorbance27 antes de imputación: 0
# NaNs en absorbance27 después de imputación: 0
# NaNs en absorbance28 antes de imputación: 0
# NaNs en absorbance28 después de imputación: 0
# NaNs en absorbance29 antes de imputación: 0
# NaNs en absorbance29 después de imputación: 0
# NaNs en absorbance30 antes de imputación: 0
# NaNs en absorbance30 después de imputación: 0
# NaNs en absorbance31 antes de imputación: 0
# NaNs en absorbance31 después de imputación: 0
# NaNs en absorbance32 antes de imputación: 0
# NaNs en absorbance32 después de imputación: 0
# NaNs en absorbance33 antes de imputación: 0
# NaNs en absorbance33 después de imputación: 0
# NaNs en absorbance34 antes de imputación: 0
# NaNs en absorbance34 después de imputación: 0
# NaNs en absorbance35 antes de imputación: 0
# NaNs en absorbance35 después de imputación: 0
# NaNs en absorbance36 antes de imputación: 0
# NaNs en absorbance36 después de imputación: 0
# NaNs en absorbance37 antes de imputación: 0
# NaNs en absorbance37 después de imputación: 0
# NaNs en absorbance38 antes de imputación: 0
# NaNs en absorbance38 después de imputación: 0
# NaNs en absorbance39 antes de imputación: 0
# NaNs en absorbance39 después de imputación: 0
# NaNs en absorbance40 antes de imputación: 0
# NaNs en absorbance40 después de imputación: 0
# NaNs en absorbance41 antes de imputación: 0
# NaNs en absorbance41 después de imputación: 0
# NaNs en absorbance42 antes de imputación: 0
# NaNs en absorbance42 después de imputación: 0
# NaNs en absorbance43 antes de imputación: 0
# NaNs en absorbance43 después de imputación: 0
# NaNs en absorbance44 antes de imputación: 0
# NaNs en absorbance44 después de imputación: 0
# NaNs en absorbance45 antes de imputación: 0
# NaNs en absorbance45 después de imputación: 0
# NaNs en absorbance46 antes de imputación: 0
# NaNs en absorbance46 después de imputación: 0
# NaNs en absorbance47 antes de imputación: 0
# NaNs en absorbance47 después de imputación: 0
# NaNs en absorbance48 antes de imputación: 0
# NaNs en absorbance48 después de imputación: 0
# NaNs en absorbance49 antes de imputación: 0
# NaNs en absorbance49 después de imputación: 0
# NaNs en absorbance50 antes de imputación: 0
# NaNs en absorbance50 después de imputación: 0
# NaNs en absorbance51 antes de imputación: 0
# NaNs en absorbance51 después de imputación: 0
# NaNs en absorbance52 antes de imputación: 0
# NaNs en absorbance52 después de imputación: 0
# NaNs en absorbance53 antes de imputación: 0
# NaNs en absorbance53 después de imputación: 0
# NaNs en absorbance54 antes de imputación: 0
# NaNs en absorbance54 después de imputación: 0
# NaNs en absorbance55 antes de imputación: 0
# NaNs en absorbance55 después de imputación: 0
# NaNs en absorbance56 antes de imputación: 0
# NaNs en absorbance56 después de imputación: 0
# NaNs en absorbance57 antes de imputación: 0
# NaNs en absorbance57 después de imputación: 0
# NaNs en absorbance58 antes de imputación: 0
# NaNs en absorbance58 después de imputación: 0
# NaNs en absorbance59 antes de imputación: 0
# NaNs en absorbance59 después de imputación: 0
# NaNs en absorbance60 antes de imputación: 0
# NaNs en absorbance60 después de imputación: 0
# NaNs en absorbance61 antes de imputación: 0
# NaNs en absorbance61 después de imputación: 0
# NaNs en absorbance62 antes de imputación: 0
# NaNs en absorbance62 después de imputación: 0
# NaNs en absorbance63 antes de imputación: 0
# NaNs en absorbance63 después de imputación: 0
# NaNs en absorbance64 antes de imputación: 0
# NaNs en absorbance64 después de imputación: 0
# NaNs en absorbance65 antes de imputación: 0
# NaNs en absorbance65 después de imputación: 0
# NaNs en absorbance66 antes de imputación: 0
# NaNs en absorbance66 después de imputación: 0
# NaNs en absorbance67 antes de imputación: 0
# NaNs en absorbance67 después de imputación: 0
# NaNs en absorbance68 antes de imputación: 0
# NaNs en absorbance68 después de imputación: 0
# NaNs en absorbance69 antes de imputación: 0
# NaNs en absorbance69 después de imputación: 0
# NaNs en absorbance70 antes de imputación: 0
# NaNs en absorbance70 después de imputación: 0
# NaNs en absorbance71 antes de imputación: 0
# NaNs en absorbance71 después de imputación: 0
# NaNs en absorbance72 antes de imputación: 0
# NaNs en absorbance72 después de imputación: 0
# NaNs en absorbance73 antes de imputación: 0
# NaNs en absorbance73 después de imputación: 0
# NaNs en absorbance74 antes de imputación: 0
# NaNs en absorbance74 después de imputación: 0
# NaNs en absorbance75 antes de imputación: 0
# NaNs en absorbance75 después de imputación: 0
# NaNs en absorbance76 antes de imputación: 0
# NaNs en absorbance76 después de imputación: 0
# NaNs en absorbance77 antes de imputación: 0
# NaNs en absorbance77 después de imputación: 0
# NaNs en absorbance78 antes de imputación: 0
# NaNs en absorbance78 después de imputación: 0
# NaNs en absorbance79 antes de imputación: 0
# NaNs en absorbance79 después de imputación: 0
# NaNs en absorbance80 antes de imputación: 0
# NaNs en absorbance80 después de imputación: 0
# NaNs en absorbance81 antes de imputación: 0
# NaNs en absorbance81 después de imputación: 0
# NaNs en absorbance82 antes de imputación: 0
# NaNs en absorbance82 después de imputación: 0
# NaNs en absorbance83 antes de imputación: 0
# NaNs en absorbance83 después de imputación: 0
# NaNs en absorbance84 antes de imputación: 0
# NaNs en absorbance84 después de imputación: 0
# NaNs en absorbance85 antes de imputación: 0
# NaNs en absorbance85 después de imputación: 0
# NaNs en absorbance86 antes de imputación: 0
# NaNs en absorbance86 después de imputación: 0
# NaNs en absorbance87 antes de imputación: 0
# NaNs en absorbance87 después de imputación: 0
# NaNs en absorbance88 antes de imputación: 0
# NaNs en absorbance88 después de imputación: 0
# NaNs en absorbance89 antes de imputación: 0
# NaNs en absorbance89 después de imputación: 0
# NaNs en absorbance90 antes de imputación: 0
# NaNs en absorbance90 después de imputación: 0
# NaNs en absorbance91 antes de imputación: 0
# NaNs en absorbance91 después de imputación: 0
# NaNs en absorbance92 antes de imputación: 0
# NaNs en absorbance92 después de imputación: 0
# NaNs en absorbance93 antes de imputación: 0
# NaNs en absorbance93 después de imputación: 0
# NaNs en absorbance94 antes de imputación: 0
# NaNs en absorbance94 después de imputación: 0
# NaNs en absorbance95 antes de imputación: 0
# NaNs en absorbance95 después de imputación: 0
# NaNs en absorbance96 antes de imputación: 0
# NaNs en absorbance96 después de imputación: 0
# NaNs en absorbance97 antes de imputación: 0
# NaNs en absorbance97 después de imputación: 0
# NaNs en absorbance98 antes de imputación: 0
# NaNs en absorbance98 después de imputación: 0
# NaNs en absorbance99 antes de imputación: 0
# NaNs en absorbance99 después de imputación: 0
# NaNs en absorbance100 antes de imputación: 0
# NaNs en absorbance100 después de imputación: 0
# NaNs en absorbance101 antes de imputación: 0
# NaNs en absorbance101 después de imputación: 0
# NaNs en absorbance102 antes de imputación: 0
# NaNs en absorbance102 después de imputación: 0
# NaNs en absorbance103 antes de imputación: 0
# NaNs en absorbance103 después de imputación: 0
# NaNs en absorbance104 antes de imputación: 0
# NaNs en absorbance104 después de imputación: 0
# NaNs en absorbance105 antes de imputación: 0
# NaNs en absorbance105 después de imputación: 0
# NaNs en absorbance106 antes de imputación: 0
# NaNs en absorbance106 después de imputación: 0
# NaNs en absorbance107 antes de imputación: 0
# NaNs en absorbance107 después de imputación: 0
# NaNs en absorbance108 antes de imputación: 0
# NaNs en absorbance108 después de imputación: 0
# NaNs en absorbance109 antes de imputación: 0
# NaNs en absorbance109 después de imputación: 0
# NaNs en absorbance110 antes de imputación: 0
# NaNs en absorbance110 después de imputación: 0
# NaNs en absorbance111 antes de imputación: 0
# NaNs en absorbance111 después de imputación: 0
# NaNs en absorbance112 antes de imputación: 0
# NaNs en absorbance112 después de imputación: 0
# NaNs en absorbance113 antes de imputación: 0
# NaNs en absorbance113 después de imputación: 0
# NaNs en absorbance114 antes de imputación: 0
# NaNs en absorbance114 después de imputación: 0
# NaNs en absorbance115 antes de imputación: 0
# NaNs en absorbance115 después de imputación: 0
# NaNs en absorbance116 antes de imputación: 0
# NaNs en absorbance116 después de imputación: 0
# NaNs en absorbance117 antes de imputación: 0
# NaNs en absorbance117 después de imputación: 0
# NaNs en absorbance118 antes de imputación: 0
# NaNs en absorbance118 después de imputación: 0
# NaNs en absorbance119 antes de imputación: 0
# NaNs en absorbance119 después de imputación: 0
# NaNs en absorbance120 antes de imputación: 0
# NaNs en absorbance120 después de imputación: 0
# NaNs en absorbance121 antes de imputación: 0
# NaNs en absorbance121 después de imputación: 0
# NaNs en absorbance122 antes de imputación: 0
# NaNs en absorbance122 después de imputación: 0
# NaNs en absorbance123 antes de imputación: 0
# NaNs en absorbance123 después de imputación: 0
# NaNs en absorbance124 antes de imputación: 0
# NaNs en absorbance124 después de imputación: 0
# NaNs en absorbance125 antes de imputación: 0
# NaNs en absorbance125 después de imputación: 0
# NaNs en absorbance126 antes de imputación: 0
# NaNs en absorbance126 después de imputación: 0
# NaNs en absorbance127 antes de imputación: 0
# NaNs en absorbance127 después de imputación: 0
# NaNs en absorbance128 antes de imputación: 0
# NaNs en absorbance128 después de imputación: 0
# NaNs en absorbance129 antes de imputación: 0
# NaNs en absorbance129 después de imputación: 0
# NaNs en absorbance130 antes de imputación: 0
# NaNs en absorbance130 después de imputación: 0
# NaNs en absorbance131 antes de imputación: 0
# NaNs en absorbance131 después de imputación: 0
# NaNs en absorbance132 antes de imputación: 0
# NaNs en absorbance132 después de imputación: 0
# NaNs en absorbance133 antes de imputación: 0
# NaNs en absorbance133 después de imputación: 0
# NaNs en absorbance134 antes de imputación: 0
# NaNs en absorbance134 después de imputación: 0
# NaNs en absorbance135 antes de imputación: 0
# NaNs en absorbance135 después de imputación: 0
# NaNs en absorbance136 antes de imputación: 0
# NaNs en absorbance136 después de imputación: 0
# NaNs en absorbance137 antes de imputación: 0
# NaNs en absorbance137 después de imputación: 0
# NaNs en absorbance138 antes de imputación: 0
# NaNs en absorbance138 después de imputación: 0
# NaNs en absorbance139 antes de imputación: 0
# NaNs en absorbance139 después de imputación: 0
# NaNs en absorbance140 antes de imputación: 0
# NaNs en absorbance140 después de imputación: 0
# NaNs en absorbance141 antes de imputación: 0
# NaNs en absorbance141 después de imputación: 0
# NaNs en absorbance142 antes de imputación: 0
# NaNs en absorbance142 después de imputación: 0
# NaNs en absorbance143 antes de imputación: 0
# NaNs en absorbance143 después de imputación: 0
# NaNs en absorbance144 antes de imputación: 0
# NaNs en absorbance144 después de imputación: 0
# NaNs en absorbance145 antes de imputación: 0
# NaNs en absorbance145 después de imputación: 0
# NaNs en absorbance146 antes de imputación: 0
# NaNs en absorbance146 después de imputación: 0
# NaNs en absorbance147 antes de imputación: 0
# NaNs en absorbance147 después de imputación: 0
# NaNs en absorbance148 antes de imputación: 0
# NaNs en absorbance148 después de imputación: 0
# NaNs en absorbance149 antes de imputación: 0
# NaNs en absorbance149 después de imputación: 0
# NaNs en absorbance150 antes de imputación: 0
# NaNs en absorbance150 después de imputación: 0
# NaNs en absorbance151 antes de imputación: 0
# NaNs en absorbance151 después de imputación: 0
# NaNs en absorbance152 antes de imputación: 0
# NaNs en absorbance152 después de imputación: 0
# NaNs en absorbance153 antes de imputación: 0
# NaNs en absorbance153 después de imputación: 0
# NaNs en absorbance154 antes de imputación: 0
# NaNs en absorbance154 después de imputación: 0
# NaNs en absorbance155 antes de imputación: 0
# NaNs en absorbance155 después de imputación: 0
# NaNs en absorbance156 antes de imputación: 0
# NaNs en absorbance156 después de imputación: 0
# NaNs en absorbance157 antes de imputación: 0
# NaNs en absorbance157 después de imputación: 0
# NaNs en absorbance158 antes de imputación: 0
# NaNs en absorbance158 después de imputación: 0
# NaNs en absorbance159 antes de imputación: 0
# NaNs en absorbance159 después de imputación: 0
# NaNs en absorbance160 antes de imputación: 0
# NaNs en absorbance160 después de imputación: 0
# NaNs en absorbance161 antes de imputación: 0
# NaNs en absorbance161 después de imputación: 0
# NaNs en absorbance162 antes de imputación: 0
# NaNs en absorbance162 después de imputación: 0
# NaNs en absorbance163 antes de imputación: 0
# NaNs en absorbance163 después de imputación: 0
# NaNs en absorbance164 antes de imputación: 0
# NaNs en absorbance164 después de imputación: 0
# NaNs en absorbance165 antes de imputación: 0
# NaNs en absorbance165 después de imputación: 0
# NaNs en absorbance166 antes de imputación: 0
# NaNs en absorbance166 después de imputación: 0
# NaNs en absorbance167 antes de imputación: 0
# NaNs en absorbance167 después de imputación: 0
# NaNs en absorbance168 antes de imputación: 0
# NaNs en absorbance168 después de imputación: 0
# NaNs en absorbance169 antes de imputación: 0
# NaNs en absorbance169 después de imputación: 0
# NaNs en temperature antes de imputación: 0
# NaNs en temperature después de imputación: 0
# NaNs en humidity antes de imputación: 0
# NaNs en humidity después de imputación: 0
# Epoch 1/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 2.8755 - salida_0_loss: 1.4792 - salida_0_mae: 0.9593 - salida_1_loss: 1.3963 - salida_1_mae: 0.9043 - val_loss: 0.4476 - val_salida_0_loss: 0.3358 - val_salida_0_mae: 0.4576 - val_salida_1_loss: 0.1087 - val_salida_1_mae: 0.2162
# Epoch 2/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8333 - salida_0_loss: 0.5261 - salida_0_mae: 0.5775 - salida_1_loss: 0.3072 - salida_1_mae: 0.4200 - val_loss: 0.4003 - val_salida_0_loss: 0.3024 - val_salida_0_mae: 0.4238 - val_salida_1_loss: 0.0948 - val_salida_1_mae: 0.1788
# Epoch 3/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5823 - salida_0_loss: 0.4054 - salida_0_mae: 0.5036 - salida_1_loss: 0.1769 - salida_1_mae: 0.3084 - val_loss: 0.3882 - val_salida_0_loss: 0.2941 - val_salida_0_mae: 0.4163 - val_salida_1_loss: 0.0910 - val_salida_1_mae: 0.1714
# Epoch 4/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.5115 - salida_0_loss: 0.3742 - salida_0_mae: 0.4826 - salida_1_loss: 0.1374 - salida_1_mae: 0.2599 - val_loss: 0.3831 - val_salida_0_loss: 0.2905 - val_salida_0_mae: 0.4181 - val_salida_1_loss: 0.0893 - val_salida_1_mae: 0.1654
# Epoch 5/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.4700 - salida_0_loss: 0.3522 - salida_0_mae: 0.4632 - salida_1_loss: 0.1178 - salida_1_mae: 0.2299 - val_loss: 0.3747 - val_salida_0_loss: 0.2839 - val_salida_0_mae: 0.4046 - val_salida_1_loss: 0.0876 - val_salida_1_mae: 0.1669
# Epoch 6/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4462 - salida_0_loss: 0.3376 - salida_0_mae: 0.4570 - salida_1_loss: 0.1086 - salida_1_mae: 0.2140 - val_loss: 0.3624 - val_salida_0_loss: 0.2711 - val_salida_0_mae: 0.4020 - val_salida_1_loss: 0.0879 - val_salida_1_mae: 0.1598
# Epoch 7/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4268 - salida_0_loss: 0.3248 - salida_0_mae: 0.4480 - salida_1_loss: 0.1021 - salida_1_mae: 0.2021 - val_loss: 0.3556 - val_salida_0_loss: 0.2660 - val_salida_0_mae: 0.3941 - val_salida_1_loss: 0.0864 - val_salida_1_mae: 0.1645
# Epoch 8/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.4200 - salida_0_loss: 0.3203 - salida_0_mae: 0.4420 - salida_1_loss: 0.0997 - salida_1_mae: 0.1952 - val_loss: 0.3415 - val_salida_0_loss: 0.2512 - val_salida_0_mae: 0.3872 - val_salida_1_loss: 0.0871 - val_salida_1_mae: 0.1596
# Epoch 9/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4040 - salida_0_loss: 0.3088 - salida_0_mae: 0.4397 - salida_1_loss: 0.0952 - salida_1_mae: 0.1889 - val_loss: 0.3312 - val_salida_0_loss: 0.2432 - val_salida_0_mae: 0.3827 - val_salida_1_loss: 0.0850 - val_salida_1_mae: 0.1563
# Epoch 10/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.3987 - salida_0_loss: 0.3078 - salida_0_mae: 0.4363 - salida_1_loss: 0.0909 - salida_1_mae: 0.1812 - val_loss: 0.3136 - val_salida_0_loss: 0.2267 - val_salida_0_mae: 0.3671 - val_salida_1_loss: 0.0841 - val_salida_1_mae: 0.1710
# Epoch 11/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.3871 - salida_0_loss: 0.2939 - salida_0_mae: 0.4267 - salida_1_loss: 0.0933 - salida_1_mae: 0.1858 - val_loss: 0.3060 - val_salida_0_loss: 0.2207 - val_salida_0_mae: 0.3639 - val_salida_1_loss: 0.0828 - val_salida_1_mae: 0.1585
# Epoch 12/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3731 - salida_0_loss: 0.2817 - salida_0_mae: 0.4187 - salida_1_loss: 0.0914 - salida_1_mae: 0.1832 - val_loss: 0.2985 - val_salida_0_loss: 0.2120 - val_salida_0_mae: 0.3536 - val_salida_1_loss: 0.0837 - val_salida_1_mae: 0.1556
# Epoch 13/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3642 - salida_0_loss: 0.2737 - salida_0_mae: 0.4105 - salida_1_loss: 0.0904 - salida_1_mae: 0.1819 - val_loss: 0.2852 - val_salida_0_loss: 0.2018 - val_salida_0_mae: 0.3436 - val_salida_1_loss: 0.0808 - val_salida_1_mae: 0.1608
# Epoch 14/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3583 - salida_0_loss: 0.2690 - salida_0_mae: 0.4069 - salida_1_loss: 0.0893 - salida_1_mae: 0.1815 - val_loss: 0.2769 - val_salida_0_loss: 0.1934 - val_salida_0_mae: 0.3395 - val_salida_1_loss: 0.0809 - val_salida_1_mae: 0.1540
# Epoch 15/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.3435 - salida_0_loss: 0.2573 - salida_0_mae: 0.3975 - salida_1_loss: 0.0862 - salida_1_mae: 0.1785 - val_loss: 0.2642 - val_salida_0_loss: 0.1843 - val_salida_0_mae: 0.3333 - val_salida_1_loss: 0.0775 - val_salida_1_mae: 0.1629
# Epoch 16/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.3437 - salida_0_loss: 0.2575 - salida_0_mae: 0.4013 - salida_1_loss: 0.0862 - salida_1_mae: 0.1834 - val_loss: 0.2565 - val_salida_0_loss: 0.1795 - val_salida_0_mae: 0.3238 - val_salida_1_loss: 0.0747 - val_salida_1_mae: 0.1565
# Epoch 17/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.3335 - salida_0_loss: 0.2447 - salida_0_mae: 0.3898 - salida_1_loss: 0.0888 - salida_1_mae: 0.1875 - val_loss: 0.2464 - val_salida_0_loss: 0.1711 - val_salida_0_mae: 0.3150 - val_salida_1_loss: 0.0731 - val_salida_1_mae: 0.1531
# Epoch 18/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3267 - salida_0_loss: 0.2411 - salida_0_mae: 0.3844 - salida_1_loss: 0.0856 - salida_1_mae: 0.1836 - val_loss: 0.2405 - val_salida_0_loss: 0.1666 - val_salida_0_mae: 0.3151 - val_salida_1_loss: 0.0719 - val_salida_1_mae: 0.1535
# Epoch 19/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3201 - salida_0_loss: 0.2332 - salida_0_mae: 0.3770 - salida_1_loss: 0.0869 - salida_1_mae: 0.1858 - val_loss: 0.2306 - val_salida_0_loss: 0.1600 - val_salida_0_mae: 0.3078 - val_salida_1_loss: 0.0685 - val_salida_1_mae: 0.1536
# Epoch 20/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3195 - salida_0_loss: 0.2366 - salida_0_mae: 0.3808 - salida_1_loss: 0.0828 - salida_1_mae: 0.1831 - val_loss: 0.2288 - val_salida_0_loss: 0.1576 - val_salida_0_mae: 0.3038 - val_salida_1_loss: 0.0691 - val_salida_1_mae: 0.1525
# Epoch 21/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.3063 - salida_0_loss: 0.2229 - salida_0_mae: 0.3706 - salida_1_loss: 0.0835 - salida_1_mae: 0.1846 - val_loss: 0.2160 - val_salida_0_loss: 0.1472 - val_salida_0_mae: 0.2921 - val_salida_1_loss: 0.0668 - val_salida_1_mae: 0.1458
# Epoch 22/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2897 - salida_0_loss: 0.2134 - salida_0_mae: 0.3623 - salida_1_loss: 0.0763 - salida_1_mae: 0.1766 - val_loss: 0.2146 - val_salida_0_loss: 0.1473 - val_salida_0_mae: 0.2936 - val_salida_1_loss: 0.0651 - val_salida_1_mae: 0.1536
# Epoch 23/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2863 - salida_0_loss: 0.2124 - salida_0_mae: 0.3589 - salida_1_loss: 0.0739 - salida_1_mae: 0.1785 - val_loss: 0.2064 - val_salida_0_loss: 0.1415 - val_salida_0_mae: 0.2839 - val_salida_1_loss: 0.0631 - val_salida_1_mae: 0.1471
# Epoch 24/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2880 - salida_0_loss: 0.2129 - salida_0_mae: 0.3620 - salida_1_loss: 0.0751 - salida_1_mae: 0.1789 - val_loss: 0.2009 - val_salida_0_loss: 0.1364 - val_salida_0_mae: 0.2785 - val_salida_1_loss: 0.0626 - val_salida_1_mae: 0.1435
# Epoch 25/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2847 - salida_0_loss: 0.2106 - salida_0_mae: 0.3598 - salida_1_loss: 0.0741 - salida_1_mae: 0.1764 - val_loss: 0.1991 - val_salida_0_loss: 0.1356 - val_salida_0_mae: 0.2800 - val_salida_1_loss: 0.0616 - val_salida_1_mae: 0.1446
# Epoch 26/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2853 - salida_0_loss: 0.2087 - salida_0_mae: 0.3579 - salida_1_loss: 0.0766 - salida_1_mae: 0.1792 - val_loss: 0.1920 - val_salida_0_loss: 0.1314 - val_salida_0_mae: 0.2741 - val_salida_1_loss: 0.0588 - val_salida_1_mae: 0.1424
# Epoch 27/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2751 - salida_0_loss: 0.2013 - salida_0_mae: 0.3498 - salida_1_loss: 0.0737 - salida_1_mae: 0.1779 - val_loss: 0.1932 - val_salida_0_loss: 0.1321 - val_salida_0_mae: 0.2754 - val_salida_1_loss: 0.0592 - val_salida_1_mae: 0.1414
# Epoch 28/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2699 - salida_0_loss: 0.1972 - salida_0_mae: 0.3471 - salida_1_loss: 0.0727 - salida_1_mae: 0.1748 - val_loss: 0.1864 - val_salida_0_loss: 0.1288 - val_salida_0_mae: 0.2711 - val_salida_1_loss: 0.0560 - val_salida_1_mae: 0.1442
# Epoch 29/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2679 - salida_0_loss: 0.1964 - salida_0_mae: 0.3478 - salida_1_loss: 0.0716 - salida_1_mae: 0.1785 - val_loss: 0.1795 - val_salida_0_loss: 0.1215 - val_salida_0_mae: 0.2658 - val_salida_1_loss: 0.0565 - val_salida_1_mae: 0.1421
# Epoch 30/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2587 - salida_0_loss: 0.1903 - salida_0_mae: 0.3411 - salida_1_loss: 0.0684 - salida_1_mae: 0.1741 - val_loss: 0.1736 - val_salida_0_loss: 0.1170 - val_salida_0_mae: 0.2562 - val_salida_1_loss: 0.0550 - val_salida_1_mae: 0.1357
# Epoch 31/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.2557 - salida_0_loss: 0.1903 - salida_0_mae: 0.3385 - salida_1_loss: 0.0655 - salida_1_mae: 0.1679 - val_loss: 0.1756 - val_salida_0_loss: 0.1188 - val_salida_0_mae: 0.2575 - val_salida_1_loss: 0.0552 - val_salida_1_mae: 0.1364
# Epoch 32/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2530 - salida_0_loss: 0.1835 - salida_0_mae: 0.3349 - salida_1_loss: 0.0695 - salida_1_mae: 0.1740 - val_loss: 0.1684 - val_salida_0_loss: 0.1154 - val_salida_0_mae: 0.2494 - val_salida_1_loss: 0.0515 - val_salida_1_mae: 0.1360
# Epoch 33/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2538 - salida_0_loss: 0.1852 - salida_0_mae: 0.3349 - salida_1_loss: 0.0686 - salida_1_mae: 0.1736 - val_loss: 0.1684 - val_salida_0_loss: 0.1132 - val_salida_0_mae: 0.2490 - val_salida_1_loss: 0.0536 - val_salida_1_mae: 0.1331
# Epoch 34/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.2510 - salida_0_loss: 0.1854 - salida_0_mae: 0.3347 - salida_1_loss: 0.0657 - salida_1_mae: 0.1704 - val_loss: 0.1574 - val_salida_0_loss: 0.1079 - val_salida_0_mae: 0.2477 - val_salida_1_loss: 0.0481 - val_salida_1_mae: 0.1352
# Epoch 35/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2543 - salida_0_loss: 0.1892 - salida_0_mae: 0.3402 - salida_1_loss: 0.0651 - salida_1_mae: 0.1713 - val_loss: 0.1663 - val_salida_0_loss: 0.1160 - val_salida_0_mae: 0.2563 - val_salida_1_loss: 0.0489 - val_salida_1_mae: 0.1310
# Epoch 36/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2423 - salida_0_loss: 0.1790 - salida_0_mae: 0.3285 - salida_1_loss: 0.0633 - salida_1_mae: 0.1680 - val_loss: 0.1535 - val_salida_0_loss: 0.1047 - val_salida_0_mae: 0.2463 - val_salida_1_loss: 0.0474 - val_salida_1_mae: 0.1287
# Epoch 37/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2436 - salida_0_loss: 0.1817 - salida_0_mae: 0.3307 - salida_1_loss: 0.0619 - salida_1_mae: 0.1675 - val_loss: 0.1574 - val_salida_0_loss: 0.1069 - val_salida_0_mae: 0.2448 - val_salida_1_loss: 0.0490 - val_salida_1_mae: 0.1275
# Epoch 38/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2411 - salida_0_loss: 0.1751 - salida_0_mae: 0.3253 - salida_1_loss: 0.0660 - salida_1_mae: 0.1691 - val_loss: 0.1522 - val_salida_0_loss: 0.1056 - val_salida_0_mae: 0.2456 - val_salida_1_loss: 0.0453 - val_salida_1_mae: 0.1275
# Epoch 39/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2410 - salida_0_loss: 0.1764 - salida_0_mae: 0.3289 - salida_1_loss: 0.0646 - salida_1_mae: 0.1691 - val_loss: 0.1492 - val_salida_0_loss: 0.1004 - val_salida_0_mae: 0.2358 - val_salida_1_loss: 0.0475 - val_salida_1_mae: 0.1239
# Epoch 40/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2288 - salida_0_loss: 0.1665 - salida_0_mae: 0.3155 - salida_1_loss: 0.0623 - salida_1_mae: 0.1642 - val_loss: 0.1472 - val_salida_0_loss: 0.1021 - val_salida_0_mae: 0.2382 - val_salida_1_loss: 0.0438 - val_salida_1_mae: 0.1240
# Epoch 41/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.2327 - salida_0_loss: 0.1700 - salida_0_mae: 0.3196 - salida_1_loss: 0.0626 - salida_1_mae: 0.1681 - val_loss: 0.1472 - val_salida_0_loss: 0.0994 - val_salida_0_mae: 0.2323 - val_salida_1_loss: 0.0467 - val_salida_1_mae: 0.1215
# Epoch 42/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2302 - salida_0_loss: 0.1681 - salida_0_mae: 0.3181 - salida_1_loss: 0.0621 - salida_1_mae: 0.1648 - val_loss: 0.1439 - val_salida_0_loss: 0.0992 - val_salida_0_mae: 0.2333 - val_salida_1_loss: 0.0434 - val_salida_1_mae: 0.1206
# Epoch 43/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2294 - salida_0_loss: 0.1684 - salida_0_mae: 0.3176 - salida_1_loss: 0.0611 - salida_1_mae: 0.1627 - val_loss: 0.1469 - val_salida_0_loss: 0.1019 - val_salida_0_mae: 0.2368 - val_salida_1_loss: 0.0438 - val_salida_1_mae: 0.1190
# Epoch 44/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2331 - salida_0_loss: 0.1698 - salida_0_mae: 0.3181 - salida_1_loss: 0.0632 - salida_1_mae: 0.1639 - val_loss: 0.1418 - val_salida_0_loss: 0.0938 - val_salida_0_mae: 0.2283 - val_salida_1_loss: 0.0468 - val_salida_1_mae: 0.1214
# Epoch 45/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2239 - salida_0_loss: 0.1660 - salida_0_mae: 0.3154 - salida_1_loss: 0.0579 - salida_1_mae: 0.1573 - val_loss: 0.1425 - val_salida_0_loss: 0.0993 - val_salida_0_mae: 0.2310 - val_salida_1_loss: 0.0420 - val_salida_1_mae: 0.1187
# Epoch 46/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2198 - salida_0_loss: 0.1635 - salida_0_mae: 0.3145 - salida_1_loss: 0.0563 - salida_1_mae: 0.1572 - val_loss: 0.1339 - val_salida_0_loss: 0.0921 - val_salida_0_mae: 0.2263 - val_salida_1_loss: 0.0406 - val_salida_1_mae: 0.1127
# Epoch 47/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2223 - salida_0_loss: 0.1650 - salida_0_mae: 0.3135 - salida_1_loss: 0.0573 - salida_1_mae: 0.1578 - val_loss: 0.1308 - val_salida_0_loss: 0.0907 - val_salida_0_mae: 0.2235 - val_salida_1_loss: 0.0391 - val_salida_1_mae: 0.1145
# Epoch 48/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.2151 - salida_0_loss: 0.1565 - salida_0_mae: 0.3051 - salida_1_loss: 0.0586 - salida_1_mae: 0.1596 - val_loss: 0.1334 - val_salida_0_loss: 0.0904 - val_salida_0_mae: 0.2222 - val_salida_1_loss: 0.0420 - val_salida_1_mae: 0.1164
# Epoch 49/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.2174 - salida_0_loss: 0.1598 - salida_0_mae: 0.3112 - salida_1_loss: 0.0576 - salida_1_mae: 0.1573 - val_loss: 0.1319 - val_salida_0_loss: 0.0894 - val_salida_0_mae: 0.2235 - val_salida_1_loss: 0.0414 - val_salida_1_mae: 0.1169
# Epoch 50/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2130 - salida_0_loss: 0.1558 - salida_0_mae: 0.3062 - salida_1_loss: 0.0572 - salida_1_mae: 0.1590 - val_loss: 0.1272 - val_salida_0_loss: 0.0839 - val_salida_0_mae: 0.2154 - val_salida_1_loss: 0.0424 - val_salida_1_mae: 0.1134
# Epoch 51/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2061 - salida_0_loss: 0.1492 - salida_0_mae: 0.3000 - salida_1_loss: 0.0568 - salida_1_mae: 0.1540 - val_loss: 0.1241 - val_salida_0_loss: 0.0879 - val_salida_0_mae: 0.2204 - val_salida_1_loss: 0.0354 - val_salida_1_mae: 0.1092
# Epoch 52/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2209 - salida_0_loss: 0.1614 - salida_0_mae: 0.3098 - salida_1_loss: 0.0595 - salida_1_mae: 0.1566 - val_loss: 0.1236 - val_salida_0_loss: 0.0831 - val_salida_0_mae: 0.2138 - val_salida_1_loss: 0.0395 - val_salida_1_mae: 0.1100
# Epoch 53/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2057 - salida_0_loss: 0.1501 - salida_0_mae: 0.3013 - salida_1_loss: 0.0557 - salida_1_mae: 0.1512 - val_loss: 0.1322 - val_salida_0_loss: 0.0909 - val_salida_0_mae: 0.2198 - val_salida_1_loss: 0.0401 - val_salida_1_mae: 0.1097
# Epoch 54/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.2153 - salida_0_loss: 0.1590 - salida_0_mae: 0.3058 - salida_1_loss: 0.0564 - salida_1_mae: 0.1517 - val_loss: 0.1220 - val_salida_0_loss: 0.0844 - val_salida_0_mae: 0.2164 - val_salida_1_loss: 0.0366 - val_salida_1_mae: 0.1028
# Epoch 55/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2120 - salida_0_loss: 0.1566 - salida_0_mae: 0.3074 - salida_1_loss: 0.0554 - salida_1_mae: 0.1496 - val_loss: 0.1228 - val_salida_0_loss: 0.0877 - val_salida_0_mae: 0.2197 - val_salida_1_loss: 0.0340 - val_salida_1_mae: 0.1074
# Epoch 56/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2019 - salida_0_loss: 0.1488 - salida_0_mae: 0.2966 - salida_1_loss: 0.0532 - salida_1_mae: 0.1489 - val_loss: 0.1134 - val_salida_0_loss: 0.0781 - val_salida_0_mae: 0.2095 - val_salida_1_loss: 0.0344 - val_salida_1_mae: 0.1009
# Epoch 57/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2104 - salida_0_loss: 0.1545 - salida_0_mae: 0.3043 - salida_1_loss: 0.0558 - salida_1_mae: 0.1523 - val_loss: 0.1179 - val_salida_0_loss: 0.0819 - val_salida_0_mae: 0.2135 - val_salida_1_loss: 0.0350 - val_salida_1_mae: 0.1038
# Epoch 58/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2023 - salida_0_loss: 0.1464 - salida_0_mae: 0.2964 - salida_1_loss: 0.0559 - salida_1_mae: 0.1532 - val_loss: 0.1211 - val_salida_0_loss: 0.0833 - val_salida_0_mae: 0.2066 - val_salida_1_loss: 0.0369 - val_salida_1_mae: 0.1038
# Epoch 59/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1992 - salida_0_loss: 0.1485 - salida_0_mae: 0.2971 - salida_1_loss: 0.0507 - salida_1_mae: 0.1424 - val_loss: 0.1149 - val_salida_0_loss: 0.0775 - val_salida_0_mae: 0.2050 - val_salida_1_loss: 0.0364 - val_salida_1_mae: 0.1018
# Epoch 60/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2017 - salida_0_loss: 0.1491 - salida_0_mae: 0.3001 - salida_1_loss: 0.0526 - salida_1_mae: 0.1458 - val_loss: 0.1162 - val_salida_0_loss: 0.0775 - val_salida_0_mae: 0.2071 - val_salida_1_loss: 0.0377 - val_salida_1_mae: 0.1052
# Epoch 61/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1980 - salida_0_loss: 0.1469 - salida_0_mae: 0.2955 - salida_1_loss: 0.0511 - salida_1_mae: 0.1417 - val_loss: 0.1184 - val_salida_0_loss: 0.0825 - val_salida_0_mae: 0.2144 - val_salida_1_loss: 0.0352 - val_salida_1_mae: 0.1038
# Epoch 62/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.1990 - salida_0_loss: 0.1459 - salida_0_mae: 0.2946 - salida_1_loss: 0.0531 - salida_1_mae: 0.1471 - val_loss: 0.1193 - val_salida_0_loss: 0.0788 - val_salida_0_mae: 0.2055 - val_salida_1_loss: 0.0395 - val_salida_1_mae: 0.1033
# Epoch 63/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1969 - salida_0_loss: 0.1464 - salida_0_mae: 0.2943 - salida_1_loss: 0.0504 - salida_1_mae: 0.1399 - val_loss: 0.1107 - val_salida_0_loss: 0.0725 - val_salida_0_mae: 0.1997 - val_salida_1_loss: 0.0373 - val_salida_1_mae: 0.1026
# Epoch 64/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.1979 - salida_0_loss: 0.1464 - salida_0_mae: 0.2941 - salida_1_loss: 0.0516 - salida_1_mae: 0.1443 - val_loss: 0.1167 - val_salida_0_loss: 0.0807 - val_salida_0_mae: 0.2084 - val_salida_1_loss: 0.0353 - val_salida_1_mae: 0.1023
# Epoch 65/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1964 - salida_0_loss: 0.1442 - salida_0_mae: 0.2915 - salida_1_loss: 0.0523 - salida_1_mae: 0.1451 - val_loss: 0.1088 - val_salida_0_loss: 0.0723 - val_salida_0_mae: 0.1982 - val_salida_1_loss: 0.0359 - val_salida_1_mae: 0.0972
# Epoch 66/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.1937 - salida_0_loss: 0.1419 - salida_0_mae: 0.2895 - salida_1_loss: 0.0518 - salida_1_mae: 0.1443 - val_loss: 0.1097 - val_salida_0_loss: 0.0755 - val_salida_0_mae: 0.2029 - val_salida_1_loss: 0.0334 - val_salida_1_mae: 0.0992
# Epoch 67/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1930 - salida_0_loss: 0.1413 - salida_0_mae: 0.2873 - salida_1_loss: 0.0517 - salida_1_mae: 0.1441 - val_loss: 0.1086 - val_salida_0_loss: 0.0740 - val_salida_0_mae: 0.2004 - val_salida_1_loss: 0.0338 - val_salida_1_mae: 0.1029
# Epoch 68/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1924 - salida_0_loss: 0.1414 - salida_0_mae: 0.2875 - salida_1_loss: 0.0510 - salida_1_mae: 0.1425 - val_loss: 0.1101 - val_salida_0_loss: 0.0712 - val_salida_0_mae: 0.1975 - val_salida_1_loss: 0.0378 - val_salida_1_mae: 0.1018
# Epoch 69/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1950 - salida_0_loss: 0.1468 - salida_0_mae: 0.2918 - salida_1_loss: 0.0483 - salida_1_mae: 0.1393 - val_loss: 0.1062 - val_salida_0_loss: 0.0718 - val_salida_0_mae: 0.1948 - val_salida_1_loss: 0.0334 - val_salida_1_mae: 0.0984
# Epoch 70/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1940 - salida_0_loss: 0.1434 - salida_0_mae: 0.2896 - salida_1_loss: 0.0505 - salida_1_mae: 0.1448 - val_loss: 0.1004 - val_salida_0_loss: 0.0676 - val_salida_0_mae: 0.1901 - val_salida_1_loss: 0.0319 - val_salida_1_mae: 0.0935
# Epoch 71/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1866 - salida_0_loss: 0.1343 - salida_0_mae: 0.2807 - salida_1_loss: 0.0523 - salida_1_mae: 0.1427 - val_loss: 0.1081 - val_salida_0_loss: 0.0758 - val_salida_0_mae: 0.2017 - val_salida_1_loss: 0.0313 - val_salida_1_mae: 0.0913
# Epoch 72/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1879 - salida_0_loss: 0.1359 - salida_0_mae: 0.2835 - salida_1_loss: 0.0521 - salida_1_mae: 0.1405 - val_loss: 0.1056 - val_salida_0_loss: 0.0731 - val_salida_0_mae: 0.1988 - val_salida_1_loss: 0.0316 - val_salida_1_mae: 0.1006
# Epoch 73/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1934 - salida_0_loss: 0.1401 - salida_0_mae: 0.2863 - salida_1_loss: 0.0533 - salida_1_mae: 0.1446 - val_loss: 0.1116 - val_salida_0_loss: 0.0758 - val_salida_0_mae: 0.2053 - val_salida_1_loss: 0.0348 - val_salida_1_mae: 0.0954
# Epoch 74/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1918 - salida_0_loss: 0.1404 - salida_0_mae: 0.2883 - salida_1_loss: 0.0514 - salida_1_mae: 0.1413 - val_loss: 0.1112 - val_salida_0_loss: 0.0750 - val_salida_0_mae: 0.2014 - val_salida_1_loss: 0.0352 - val_salida_1_mae: 0.0977
# Epoch 75/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1838 - salida_0_loss: 0.1365 - salida_0_mae: 0.2832 - salida_1_loss: 0.0473 - salida_1_mae: 0.1369 - val_loss: 0.1133 - val_salida_0_loss: 0.0759 - val_salida_0_mae: 0.2036 - val_salida_1_loss: 0.0363 - val_salida_1_mae: 0.0993
# Epoch 76/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1843 - salida_0_loss: 0.1348 - salida_0_mae: 0.2810 - salida_1_loss: 0.0495 - salida_1_mae: 0.1380 - val_loss: 0.0972 - val_salida_0_loss: 0.0651 - val_salida_0_mae: 0.1904 - val_salida_1_loss: 0.0311 - val_salida_1_mae: 0.0933
# Epoch 77/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1911 - salida_0_loss: 0.1405 - salida_0_mae: 0.2869 - salida_1_loss: 0.0506 - salida_1_mae: 0.1375 - val_loss: 0.1052 - val_salida_0_loss: 0.0680 - val_salida_0_mae: 0.1936 - val_salida_1_loss: 0.0362 - val_salida_1_mae: 0.0965
# Epoch 78/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1929 - salida_0_loss: 0.1410 - salida_0_mae: 0.2867 - salida_1_loss: 0.0519 - salida_1_mae: 0.1396 - val_loss: 0.1160 - val_salida_0_loss: 0.0782 - val_salida_0_mae: 0.2106 - val_salida_1_loss: 0.0369 - val_salida_1_mae: 0.0963
# Epoch 79/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1798 - salida_0_loss: 0.1334 - salida_0_mae: 0.2794 - salida_1_loss: 0.0464 - salida_1_mae: 0.1312 - val_loss: 0.0940 - val_salida_0_loss: 0.0631 - val_salida_0_mae: 0.1867 - val_salida_1_loss: 0.0301 - val_salida_1_mae: 0.0886
# Epoch 80/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1792 - salida_0_loss: 0.1333 - salida_0_mae: 0.2815 - salida_1_loss: 0.0459 - salida_1_mae: 0.1302 - val_loss: 0.0987 - val_salida_0_loss: 0.0686 - val_salida_0_mae: 0.1941 - val_salida_1_loss: 0.0292 - val_salida_1_mae: 0.0902
# Epoch 81/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1829 - salida_0_loss: 0.1326 - salida_0_mae: 0.2790 - salida_1_loss: 0.0502 - salida_1_mae: 0.1365 - val_loss: 0.1080 - val_salida_0_loss: 0.0715 - val_salida_0_mae: 0.1955 - val_salida_1_loss: 0.0356 - val_salida_1_mae: 0.0951
# Epoch 82/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1817 - salida_0_loss: 0.1326 - salida_0_mae: 0.2777 - salida_1_loss: 0.0491 - salida_1_mae: 0.1336 - val_loss: 0.1043 - val_salida_0_loss: 0.0687 - val_salida_0_mae: 0.1939 - val_salida_1_loss: 0.0346 - val_salida_1_mae: 0.0893
# Epoch 83/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.1798 - salida_0_loss: 0.1307 - salida_0_mae: 0.2783 - salida_1_loss: 0.0491 - salida_1_mae: 0.1318 - val_loss: 0.1084 - val_salida_0_loss: 0.0730 - val_salida_0_mae: 0.1967 - val_salida_1_loss: 0.0346 - val_salida_1_mae: 0.0915
# Epoch 84/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1852 - salida_0_loss: 0.1376 - salida_0_mae: 0.2824 - salida_1_loss: 0.0476 - salida_1_mae: 0.1320 - val_loss: 0.0984 - val_salida_0_loss: 0.0664 - val_salida_0_mae: 0.1909 - val_salida_1_loss: 0.0312 - val_salida_1_mae: 0.0980
# Epoch 85/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1846 - salida_0_loss: 0.1340 - salida_0_mae: 0.2812 - salida_1_loss: 0.0506 - salida_1_mae: 0.1342 - val_loss: 0.1079 - val_salida_0_loss: 0.0757 - val_salida_0_mae: 0.2016 - val_salida_1_loss: 0.0313 - val_salida_1_mae: 0.0923
# Epoch 86/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1795 - salida_0_loss: 0.1315 - salida_0_mae: 0.2779 - salida_1_loss: 0.0480 - salida_1_mae: 0.1326 - val_loss: 0.1024 - val_salida_0_loss: 0.0641 - val_salida_0_mae: 0.1891 - val_salida_1_loss: 0.0375 - val_salida_1_mae: 0.0964
# Epoch 87/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1821 - salida_0_loss: 0.1348 - salida_0_mae: 0.2821 - salida_1_loss: 0.0473 - salida_1_mae: 0.1319 - val_loss: 0.1009 - val_salida_0_loss: 0.0667 - val_salida_0_mae: 0.1905 - val_salida_1_loss: 0.0333 - val_salida_1_mae: 0.0913
# Epoch 88/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1811 - salida_0_loss: 0.1336 - salida_0_mae: 0.2804 - salida_1_loss: 0.0475 - salida_1_mae: 0.1308 - val_loss: 0.0957 - val_salida_0_loss: 0.0644 - val_salida_0_mae: 0.1883 - val_salida_1_loss: 0.0306 - val_salida_1_mae: 0.0885
# Epoch 89/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1742 - salida_0_loss: 0.1270 - salida_0_mae: 0.2729 - salida_1_loss: 0.0472 - salida_1_mae: 0.1324 - val_loss: 0.0930 - val_salida_0_loss: 0.0629 - val_salida_0_mae: 0.1857 - val_salida_1_loss: 0.0293 - val_salida_1_mae: 0.0850
# Epoch 90/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.1862 - salida_0_loss: 0.1384 - salida_0_mae: 0.2832 - salida_1_loss: 0.0478 - salida_1_mae: 0.1296 - val_loss: 0.0959 - val_salida_0_loss: 0.0639 - val_salida_0_mae: 0.1882 - val_salida_1_loss: 0.0310 - val_salida_1_mae: 0.0881
# Epoch 91/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1769 - salida_0_loss: 0.1317 - salida_0_mae: 0.2790 - salida_1_loss: 0.0451 - salida_1_mae: 0.1263 - val_loss: 0.1008 - val_salida_0_loss: 0.0710 - val_salida_0_mae: 0.1935 - val_salida_1_loss: 0.0291 - val_salida_1_mae: 0.0840
# Epoch 92/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1758 - salida_0_loss: 0.1279 - salida_0_mae: 0.2727 - salida_1_loss: 0.0480 - salida_1_mae: 0.1316 - val_loss: 0.0995 - val_salida_0_loss: 0.0654 - val_salida_0_mae: 0.1914 - val_salida_1_loss: 0.0334 - val_salida_1_mae: 0.0877
# Epoch 93/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.1794 - salida_0_loss: 0.1303 - salida_0_mae: 0.2766 - salida_1_loss: 0.0491 - salida_1_mae: 0.1311 - val_loss: 0.0882 - val_salida_0_loss: 0.0603 - val_salida_0_mae: 0.1805 - val_salida_1_loss: 0.0272 - val_salida_1_mae: 0.0873
# Epoch 94/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1796 - salida_0_loss: 0.1327 - salida_0_mae: 0.2805 - salida_1_loss: 0.0469 - salida_1_mae: 0.1297 - val_loss: 0.0885 - val_salida_0_loss: 0.0597 - val_salida_0_mae: 0.1789 - val_salida_1_loss: 0.0279 - val_salida_1_mae: 0.0827
# Epoch 95/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1808 - salida_0_loss: 0.1355 - salida_0_mae: 0.2829 - salida_1_loss: 0.0454 - salida_1_mae: 0.1275 - val_loss: 0.0959 - val_salida_0_loss: 0.0616 - val_salida_0_mae: 0.1861 - val_salida_1_loss: 0.0335 - val_salida_1_mae: 0.0938
# Epoch 96/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1731 - salida_0_loss: 0.1279 - salida_0_mae: 0.2734 - salida_1_loss: 0.0453 - salida_1_mae: 0.1291 - val_loss: 0.0992 - val_salida_0_loss: 0.0696 - val_salida_0_mae: 0.1935 - val_salida_1_loss: 0.0287 - val_salida_1_mae: 0.0868
# Epoch 97/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1780 - salida_0_loss: 0.1319 - salida_0_mae: 0.2770 - salida_1_loss: 0.0462 - salida_1_mae: 0.1295 - val_loss: 0.0975 - val_salida_0_loss: 0.0700 - val_salida_0_mae: 0.1950 - val_salida_1_loss: 0.0266 - val_salida_1_mae: 0.0847
# Epoch 98/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.1722 - salida_0_loss: 0.1257 - salida_0_mae: 0.2691 - salida_1_loss: 0.0465 - salida_1_mae: 0.1308 - val_loss: 0.0949 - val_salida_0_loss: 0.0677 - val_salida_0_mae: 0.1924 - val_salida_1_loss: 0.0265 - val_salida_1_mae: 0.0846
# Epoch 99/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1800 - salida_0_loss: 0.1307 - salida_0_mae: 0.2736 - salida_1_loss: 0.0493 - salida_1_mae: 0.1334 - val_loss: 0.0920 - val_salida_0_loss: 0.0614 - val_salida_0_mae: 0.1827 - val_salida_1_loss: 0.0299 - val_salida_1_mae: 0.0866
# Epoch 100/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1813 - salida_0_loss: 0.1348 - salida_0_mae: 0.2793 - salida_1_loss: 0.0464 - salida_1_mae: 0.1294 - val_loss: 0.0855 - val_salida_0_loss: 0.0584 - val_salida_0_mae: 0.1749 - val_salida_1_loss: 0.0263 - val_salida_1_mae: 0.0863
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Predicciones guardadas en 'predicciones.csv'.
